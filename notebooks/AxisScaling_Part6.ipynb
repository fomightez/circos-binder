# %% [markdown]
# # Part 6 of Axis Scaling: Smoothing Scale
#
# This page is primarily based on the following page at the Circos documentation site:
#
#
#
# - [6. Smoothing Scale](????????????)
#
#
#
# That page is found as part number 4 of the ??? part ['Axis Scaling' section](http://circos.ca/documentation/tutorials/quick_start/) of [the larger set of Circos tutorials](http://circos.ca/documentation/tutorials/).
#
#
#
# Go back to Part 5 by clicking [here &#8592;](AxisScaling_Part5.ipynb).
#
#
#
# ----
#
#
#
# 7 --- Axis Scaling
# ==================
#
# 6. Smoothing Scale
# ------------------
#
# ::: {#menu4}
# [[Lesson](/documentation/tutorials/scaling/scale_smoothing/lesson){.clean}]{.active}
# [Images](/documentation/tutorials/scaling/scale_smoothing/images){.normal}
# [Configuration](/documentation/tutorials/scaling/scale_smoothing/configuration){.normal}
# :::
#
# In the last example, I created a series of regions with gradually
# increasing/decreasing scale in order to avoid large changes in scale
# over short distances.
#
# To automate scale smoothing, each zoom block supports a smooth\_distance
# and smooth\_steps parameters. When using the smoothing feature, you
# define the zoom setting for your region of interest and then the number
# of smoothing steps and distance over which the scale smoothing is
# applied. Flanks around your zoomed region will have their scale
# progressively grow/shrink from the scale of your zoomed region to 1.

# %% [markdown]
# ```ini
# <zoom>
# chr    = hs1
# start  = 120u
# end    = 125u
# scale  = 10
# smooth_distance = 2r
# smooth_steps    = 10
# </zoom>
# ```

# %% [markdown]
# In this block, I define a 5Mb region on chromosome 1 that is expanded to
# 10x scale. The smoothing distance is 2r = 10Mb (here the \"r\" is
# relative to the size of the zoomed region) and smoothing is applied over
# 10 steps. Each smoothing step is 10Mb/10 = 1Mb and the scale decreases
# linearly across the smoothing regions.
#
# You can define the smooth\_distance parameter in relative units (r),
# chromosome units (u) or bases (b).
#
#
#
#
# ----
#
# ### Generating the plot produced by this example code
#
#
# The following two cells will generate the plot. The first cell adjusts the current working directory.

# %%
# %cd ../circos-tutorials-0.67/tutorials/7/6/
# Out:
# /home/jovyan/circos-tutorials-0.67/tutorials/7/6

# %%
# %%bash
# ../../../../circos-0.69-6/bin/circos -conf circos.conf
# Out:
# debuggroup summary 0.35s welcome to circos v0.69-6 31 July 2017 on Perl 5.022000
# debuggroup summary 0.36s current working directory /home/jovyan/circos-tutorials-0.67/tutorials/7/6
# debuggroup summary 0.36s command ../../../../circos-0.69-6/bin/circos -conf circos.conf
# debuggroup summary 0.36s loading configuration from file circos.conf
# debuggroup summary 0.36s found conf file circos.conf
# debuggroup summary 0.53s debug will appear for these features: output,summary
# debuggroup summary 0.53s bitmap output image ./circos.png
# debuggroup summary 0.53s SVG output image ./circos.svg
# debuggroup summary 0.53s parsing karyotype and organizing ideograms
# debuggroup summary 0.63s karyotype has 24 chromosomes of total size 3,095,677,436
# debuggroup summary 0.63s applying global and local scaling
# debuggroup summary 0.67s allocating image, colors and brushes
# debuggroup summary 2.85s drawing 2 ideograms of total size 492,449,996
# ...

# %% [markdown]
# View the plot in this page using the following cell.

# %%
from IPython.display import Image
Image("circos.png")

# %% [markdown]
# ----
#
# Continue on to the next part of the Axis Scaling series by clicking [here &#10145;](AxisScaling_Part7.ipynb).
#
# ----
