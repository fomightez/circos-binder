# %% [markdown]
# # Part 7 of Tick Marks, Grids and Labels: Relative Ticks
#
# This page is primarily based on the following page at the Circos documentation site:
#
#
#
# - [7. Relative Ticks](????????????)
#
#
#
# That page is found as part number 4 of the ??? part ['Tick Marks, Grids and Labels' section](http://circos.ca/documentation/tutorials/quick_start/) of [the larger set of Circos tutorials](http://circos.ca/documentation/tutorials/).
#
#
#
# Go back to Part 6 by clicking [here &#8592;](TickMarks_Part6.ipynb).
#
#
#
# ----
#
#
#
# 4 --- Tick Marks, Grids and Labels
# ==================================
#
# 7. Relative Ticks
# -----------------
#
# ::: {#menu4}
# [[Lesson](/documentation/tutorials/ticks_and_labels/relative_ticks/lesson){.clean}]{.active}
# [Images](/documentation/tutorials/ticks_and_labels/relative_ticks/images){.normal}
# [Configuration](/documentation/tutorials/ticks_and_labels/relative_ticks/configuration){.normal}
# :::
#
# Ticks can be spaced and/or labeled in relative units, with respect to
# the length of the ideogram to which they belong. Up to now, you\'ve seen
# how to label and space ticks in absolute distances (e.g. every 10 Mb),
# and this tutorial shows you how to space your ticks in relative
# distances (e.g. every 1% along ideogram).
#
# There are two independent relative tick settings: relative spacing and
# relative labels. Relative spacing is used to set the tick period to be
# relative to the ideogram (e.g. every 1%). Relative labels are used to
# format the label of the tick to be relative to the length of the
# ideogram. These two settings are independent. You can have ticks spaced
# relatively, but labeled by their absolute position, and vice versa.
#
# ### Relative Spacing
#
# To space ticks relatively, use the rspacing and spacing\_type parameter
# in the block. For example, to place ticks every 1% along the ideogram,

# %% [markdown]
# ```ini
# <ticks>
# <tick>
# spacing_type = relative
# rspacing     = 0.01
# ...
# </tick>
# ...
# </ticks>
# ```

# %% [markdown]
# Note that relative spacing parameters do not collide with absolute
# spacing, which is defined by the \"spacing\" parameter. This means that
# you can have both \"spacing\" and \"rspacing\" defined, and then toggle
# between relative and absolute spacing by defining the value of
# spacing\_type.

# %% [markdown]
# ```ini
# <ticks>
# # this tick is relatively spaced
# <tick>
# spacing      = 10u
# rspacing     = 0.01
# spacing_type = relative
# ...
# </tick>
# ```

# %% [markdown]
# ```ini
# # this tick is absolutely spaced
# <tick>
# spacing      = 10u
# rspacing     = 0.01
# spacing_type = absolute
# ...
# </tick>
# ...
# </ticks>
# ```

# %% [markdown]
# Since each tick definition is independent, you can mix relatively spaced
# ticks with absolutely spaced ticks. For example, you can have ticks
# every 10Mb and every 10% if you like.

# %% [markdown]
# ```ini
# <ticks>
# # these ticks are every 1Mb (assumes chromosome_units=1000000)
# <tick>
# spacing      = 1u
# spacing_type = absolute
# ...
# </tick>
# ```

# %% [markdown]
# ```ini
# # these ticks are every 1% of ideogram
# <tick>
# rspacing     = 0.01
# spacing_type = relative
# ...
# </tick>
# ...
# </ticks>
# ```

# %% [markdown]
# In the first example image, there are three layers of ticks: absolute
# spacing every 1Mb, relative spacing every 0.01 and relative spacing
# every 0.1. Notice that the labels for each tick layer are absolute. This
# works well for absolutely spaced ticks, but looks awkward for relatively
# spaced ticks (e.g. first tick in relative layer 0.1 is \"24\").
#
# ### Relative Labels
#
# When ticks are relatively spaced (e.g. every 1%), it makes more sense
# that their labels are relative too (e.g. appear as 1% rather than the
# corresponding absolute amount, such as 24.72 for chr1). To set the tick
# label to be relative, use the label\_relative and rmultiplier settings.

# %% [markdown]
# ```ini
# <tick>
# spacing_type   = relative
# rspacing       = 0.01
# label_relative = yes
# format         = %.2f
# ...
# </tick>
# ```

# %% [markdown]
# You can define a relative multiplier for the label so that relative
# labels like \"0.07\" can be displayed as \"7\".

# %% [markdown]
# ```ini
# <tick>
# spacing_type   = relative
# rspacing       = 0.01
# label_relative = yes
# format         = %.2f # labels will be 0.01 0.02 0.03 ...
# ...
# </tick>
# ```

# %% [markdown]
# With these settings, the tick labels will read 0.01, 0.02, \... 0.99.
# The \"rmultiplier\" works just like \"multiplier\", but is reserved for
# labels of relatively spaced ticks. If rmultiplier was set to 100, the
# tick labels would be 1.00, 2.00, \... 99.00. For example, to have ticks
# every 1% labeled 1%, 2%, \... 99%, use

# %% [markdown]
# ```ini
# <tick>
# spacing_type   = relative
# rspacing       = 0.01
# label_relative = yes
# rmultiplier    = 100 # labels will be 1 2 3 4 ...
# format         = %d
# </tick>
# ```

# %% [markdown]
# By adding a suffix, you can construct labels such as \"6%\" or \"2/10\".

# %% [markdown]
# ```ini
# <tick>
# spacing_type   = relative
# rspacing       = 0.01
# label_relative = yes
# rmultiplier    = 100
# format         = %d
# suffix         = %  # labels will be 1% 2% 3% ...
# </tick>
# ```

# %% [markdown]
# ```ini
# <tick>
# spacing_type   = relative
# rspacing       = 0.1
# label_relative = yes
# rmultiplier    = 10
# format         = %d
# suffix         = "/10" # labels will be 1/10 2/10 3/10 ...
# </tick>
# ```

# %% [markdown]
# ### relative ticks - relative to chromsomes or ideograms
#
# If a chromosome is represented by a single ideogram in its entirety,
# then the default relative tick settings, which are relative to
# chromosome size, are appropriate.
#
# However, if you are displaying a fraction of a chromosome, or are
# splitting it up into multiple ideograms, you may wish to make tick marks
# relative to the ideogram and not the chromosome. To do this, set the
# rdivisor.

# %% [markdown]
# ```ini
# <tick>
# spacing_type   = relative
# rspacing       = 0.1
# rdivisor       = ideogram
# </tick>
# ```

# %% [markdown]
# With this block, ticks will be spaced every 1/10th of the ideogram they
# belong to.
#
#
#
#
# ----
#
# ### Generating the plot produced by this example code
#
#
# The following two cells will generate the plot. The first cell adjusts the current working directory.

# %%
# %cd ../circos-tutorials-0.67/tutorials/4/7/
# Out:
# /home/jovyan/circos-tutorials-0.67/tutorials/4/7

# %%
# %%bash
# ../../../../circos-0.69-6/bin/circos -conf circos.conf
# Out:
# debuggroup summary 0.37s welcome to circos v0.69-6 31 July 2017 on Perl 5.022000
# debuggroup summary 0.38s current working directory /home/jovyan/circos-tutorials-0.67/tutorials/4/7
# debuggroup summary 0.38s command ../../../../circos-0.69-6/bin/circos -conf circos.conf
# debuggroup summary 0.38s loading configuration from file circos.conf
# debuggroup summary 0.38s found conf file circos.conf
# debuggroup summary 0.54s debug will appear for these features: output,summary
# debuggroup summary 0.54s bitmap output image ./circos.png
# debuggroup summary 0.54s SVG output image ./circos.svg
# debuggroup summary 0.54s parsing karyotype and organizing ideograms
# debuggroup summary 0.67s karyotype has 24 chromosomes of total size 3,095,677,436
# debuggroup summary 0.67s applying global and local scaling
# debuggroup summary 0.67s allocating image, colors and brushes
# debuggroup summary 2.75s drawing 1 ideograms of total size 249,250,622
# ...

# %% [markdown]
# View the plot in this page using the following cell.

# %%
from IPython.display import Image
Image("circos.png")

# %% [markdown]
# ----
#
# Continue on to the next part of the Tick Marks, Grids and Labels series by clicking [here &#10145;](TickMarks_Part8.ipynb).
#
# ----
