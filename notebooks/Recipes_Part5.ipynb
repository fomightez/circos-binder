# %% [markdown]
# # Part 5 of Recipes: Image Transparency and Background
#
# This page is primarily based on the following page at the Circos documentation site:
#
#
#
# - [5. Image Transparency and Background](????????????)
#
#
#
# That page is found as part number 4 of the ??? part ['Recipes' section](http://circos.ca/documentation/tutorials/quick_start/) of [the larger set of Circos tutorials](http://circos.ca/documentation/tutorials/).
#
#
#
# Go back to Part 4 by clicking [here &#8592;](Recipes_Part4.ipynb).
#
#
#
# ----
#
#
#
# 8 --- Recipes
# =============
#
# 5. Image Transparency and Background
# ------------------------------------
#
# ::: {#menu4}
# [[Lesson](/documentation/tutorials/recipes/transparency_background/lesson){.clean}]{.active}
# [Images](/documentation/tutorials/recipes/transparency_background/images){.normal}
# [Configuration](/documentation/tutorials/recipes/transparency_background/configuration){.normal}
# :::
#
# In addition to the colors you define in color.conf, an additional color
# called \"transparent\" is automatically defined for you. Therefore, if
# you try to define your own color of this name, your definition will be
# ignored.
#
# making background transparent
# -----------------------------
#
# To create an image with a transparent background, set the background
# color to \"transparent\".

# %% [markdown]
# ```ini
#
# ...
# background = transparent
#
# ```

# %% [markdown]
# using another image as background
# ---------------------------------
#
# To draw the image on a existing image, specify the input image file for
# the background parameter. This works only for PNG images.

# %% [markdown]
# ```ini
#
# ...
# background = data/8/background.png
#
# ```

# %% [markdown]
# The input image must be of the same size as the output Circos image (it
# must be square and have dimensions 2\*radius x 2\*radius, where radius
# is specified in the \<image\> block).
#
# Instead of drawing on an existing image, you can compose a Circos image
# with a transparent background together with a custom background during
# post-processing. However, having the ability to draw the Circos image on
# any background is useful when you automate Circos image generation and
# require a watermark or logo on each image.
#
#
#
#
# ----
#
# ### Generating the plot produced by this example code
#
#
# The following two cells will generate the plot. The first cell adjusts the current working directory.

# %%
# %cd ../circos-tutorials-0.67/tutorials/8/5/
# Out:
# /home/jovyan/circos-tutorials-0.67/tutorials/8/5

# %%
# %%bash
# ../../../../circos-0.69-6/bin/circos -conf circos.conf
# Out:
# debuggroup summary 0.40s welcome to circos v0.69-6 31 July 2017 on Perl 5.022000
# debuggroup summary 0.41s current working directory /home/jovyan/circos-tutorials-0.67/tutorials/8/5
# debuggroup summary 0.41s command ../../../../circos-0.69-6/bin/circos -conf circos.conf
# debuggroup summary 0.41s loading configuration from file circos.conf
# debuggroup summary 0.41s found conf file circos.conf
# debuggroup summary 0.61s debug will appear for these features: output,summary
# debuggroup summary 0.61s bitmap output image ./circos.png
# debuggroup summary 0.61s SVG output image ./circos.svg
# debuggroup summary 0.61s parsing karyotype and organizing ideograms
# debuggroup summary 0.61s karyotype has 1 chromosomes of total size 1,000,001
# debuggroup summary 0.61s applying global and local scaling
# debuggroup summary 0.62s allocating image, colors and brushes
# debuggroup summary 2.50s drawing 1 ideograms of total size 1,000,001
# ...

# %% [markdown]
# View the plot in this page using the following cell.

# %%
from IPython.display import Image
Image("circos.png")

# %% [markdown]
# ----
#
# Continue on to the next part of the Recipes series by clicking [here &#10145;](Recipes_Part6.ipynb).
#
# ----
