# %% [markdown]
# # Part 2 of Drawing Ideograms: Filtering
#
# This page is primarily based on the following page at the Circos documentation site:
#
#
#
# - [3. Filtering](????????????)
#
#
#
# That page is found as part number 4 of the ??? part ['Drawing Ideograms' section](http://circos.ca/documentation/tutorials/quick_start/) of [the larger set of Circos tutorials](http://circos.ca/documentation/tutorials/).
#
#
#
# Go back to Part 2 by clicking [here &#8592;](Drawing_ideograms_Part2.ipynb).
#
#
#
# ----
#
#
#
# 2 --- Drawing Ideograms
# =======================
#
# 3. Filtering
# ------------
#
# ::: {#menu4}
# [[Lesson](/documentation/tutorials/ideograms/filtering/lesson){.clean}]{.active}
# [Images](/documentation/tutorials/ideograms/filtering/images){.normal}
# [Configuration](/documentation/tutorials/ideograms/filtering/configuration){.normal}
# :::
#
# To remove ideograms from the image, the \"chromosomes\" and
# \"chromosomes\_display\_default\" configuration parameters are used.
#
# ### chromosomes\_display\_default
#
# If this is set, then any ideograms not explicitly excluded will be
# drawn. Setting this flag is useful if you want to exclude a few
# ideograms, but draw the majority of others.
#
# ### chromosomes
#
# This field is used identify which ideograms to draw and/or exclude. When
# referring to ideograms, always use the ID of the ideogram as defined in
# the karyotype file (not the ideogram\'s text label).
#
# For example,

# %% [markdown]
# ```ini
# chromosomes = hs1;hs2;hs3
# ```

# %% [markdown]
# will draw only the ideograms listed. To exclude an ideogram, preceed the
# ID with \"-\". Thus, to draw all ideograms but exclude those drawn above

# %% [markdown]
# ```ini
# chromosomes = -hs1;-hs2;-hs3
# chromosomes_display_default = yes
# ```

# %% [markdown]
# The order in which the ideogram IDs appear in the \"chromosomes\"
# parameter does not influence the order in which they are drawn. To apply
# a different order, use chromosomes\_order, discussed in another
# tutorial. Without specifying the order, the ideograms are drawn in the
# order of appearance in the karyotype file.
#
#
#
#
# ----
#
# ### Generating the plot produced by this example code
#
#
# The following two cells will generate the plot. The first cell adjusts the current working directory.

# %%
# %cd ../circos-tutorials-0.67/tutorials/2/3/
# Out:
# /home/jovyan/circos-tutorials-0.67/tutorials/2/3

# %%
# %%bash
# ../../../../circos-0.69-6/bin/circos -conf circos.conf
# Out:
# debuggroup summary 0.36s welcome to circos v0.69-6 31 July 2017 on Perl 5.022000
# debuggroup summary 0.37s current working directory /home/jovyan/circos-tutorials-0.67/tutorials/2/3
# debuggroup summary 0.37s command ../../../../circos-0.69-6/bin/circos -conf circos.conf
# debuggroup summary 0.37s loading configuration from file circos.conf
# debuggroup summary 0.37s found conf file circos.conf
# debuggroup summary 0.54s debug will appear for these features: output,summary
# debuggroup summary 0.55s bitmap output image ./circos.png
# debuggroup summary 0.55s SVG output image ./circos.svg
# debuggroup summary 0.55s parsing karyotype and organizing ideograms
# debuggroup summary 0.68s karyotype has 24 chromosomes of total size 3,095,677,436
# debuggroup summary 0.68s applying global and local scaling
# debuggroup summary 0.68s allocating image, colors and brushes
# debuggroup summary 2.70s drawing 6 ideograms of total size 1,116,284,253
# ...

# %% [markdown]
# View the plot in this page using the following cell.

# %%
from IPython.display import Image
Image("circos.png")

# %% [markdown]
# ----
#
# Continue on to the next part of the Drawing Ideograms series by clicking [here &#10145;](Drawing_ideograms_Part4.ipynb).
#
# ----
