# %%
#This cell is tagged parameters for running this template using Papermill to inject values to overwrite these.
markdown = ""
section = 99
sub_pg = 99
end_nb = False
next_nb = ""

# %%
# Parameters
markdown = "\n# Part 12 of 2D Data Tracks: Putting It All Together\n\nThis page is primarily based on the following page at the Circos documentation site:\n\n\n\n- [12. Putting It All Together](????????????)\n\n\n\nThat page is found as part number 4 of the ??? part ['2D Data Tracks' section](http://circos.ca/documentation/tutorials/quick_start/) of [the larger set of Circos tutorials](http://circos.ca/documentation/tutorials/).\n\n\n\nGo back to Part 11 by clicking [here &#8592;](2d_data_tracks_Part11.ipynb).\n\n\n\n----\n\n\n\n6 --- 2D Data Tracks\n====================\n\n12. Putting It All Together\n---------------------------\n\n::: {#menu4}\n[[Lesson](/documentation/tutorials/2d_tracks/stacking_tracks/lesson){.clean}]{.active}\n[Images](/documentation/tutorials/2d_tracks/stacking_tracks/images){.normal}\n[Configuration](/documentation/tutorials/2d_tracks/stacking_tracks/configuration){.normal}\n:::\n\nIn this example, I create an image with a large number of plot tracks\nthat include all the types previously discussed. The image looks like a\nheart attack and I don\\'t recommend that you create such monstrosities\nfor any reasons other than exploring Circos\\' syntax.\n\nSeveral of the idioms in the configuration file are worth exploring in\ndetail.\n\n### placing highlights among data layers\n\nWhen a highlight is defined as a plot block, you can use the z depth to\nplace it anywhere within other data layers.\n\nIn this figure, the highlight wedges are drawn ontop of the heatmaps,\nbut under the line, histogram, line and tile plots.\n\n### sampling data randomly\n\nYou can choose to hide data points randomly by using a rule that\nincorporates a call to a random number generator. The Perl function\nrand() returns a random number sampled uniformly from the interval\n\\[0,1).\n\n```ini\n<rule>\ncondition = rand() < 0.1\nshow      = no\n</rule>\n```\n\nIn this case, 10% of the data points, on average, will not appear. Each\ntime the image is created, a different set of points will be hidden.\n\n### formatting data randomly\n\nAlong the lines of the previous example, you can apply formatting\nrandomly to data. For example, to make 50% of the points, on average,\nred:\n\n```ini\n<rule>\ncondition = rand() < 0.5\ncolor     = red\n</rule>\n```\n\n### hiding heatmap elements\n\nYou can hide heatmap elements using the show=no idiom with a size\ncondition. You can also subvert the color list and include the\nbackground color in the list.\n\n```ini\n<plot>\ntype         = heatmap\n...\ncolor        = black,grey,vlgrey,white,lgreen,green,dgreen\n...\n</plot>\n```\n\n### adjacent histograms\n\nYou can create a floating bar plot by stacking two histograms against\none another. The outer histogram is oriented \\\"out\\\" and the inner one\nis oriented \\\"in\\\".\n\n```ini\n<plot>\ntype         = histogram\n...\norientation  = in\nr0           = 0.65r\nr1           = 0.75r\n...\n</plot>\n```\n\n```ini\n<plot>\ntype         = histogram\n...\norientation  = out\nr0           = 0.75r\nr1           = 0.85r\n...\n</plot>\n```\n\n### adjusting ideogram radius\n\nDon\\'t forget that you can adjust the radius of individual ideograms, or\nregions.\n\n```ini\nchromosomes        = hs2[a]:5-35;hs2[b]:40-75;hs2[c]:80-115;hs2[d]:120-155;hs2[e]:160-195;hs2[f]:200-240\nchromosomes_radius = a:0.95r;b:0.9r;c:0.85r;d:0.8r;e:0.75r;f:0.7r\n```\n\nThis is very useful if you need to squeeze in a data track, especially\noutside of the ideogram, but don\\'t want to disturb the overall circular\nnature of the plot. In this case, you would shift the ideogram radius in\nby, say, 200px, and then plot a 200px track outside the ideogram.\n\n"
section = 6
sub_pg = 12
end_nb = False
next_nb = "AxisScaling_Part1.ipynb"

# %%
'''from IPython.display import Markdown, display
def printmd(string):
    display(Markdown(string))
printmd(markdown)'''
print(markdown) #use this because want to be able to edit the markdown and rendering it with `printmd` diables that
# Out:
# # Part 12 of 2D Data Tracks: Putting It All Together
#
# This page is primarily based on the following page at the Circos documentation site:
#
#
#
# - [12. Putting It All Together](????????????)
#
#
#
# That page is found as part number 4 of the ??? part ['2D Data Tracks' section](http://circos.ca/documentation/tutorials/quick_start/) of [the larger set of Circos tutorials](http://circos.ca/documentation/tutorials/).
#
#
#
# Go back to Part 11 by clicking [here &#8592;](2d_data_tracks_Part11.ipynb).
#
#
#
# ----
#
#
#
# 6 --- 2D Data Tracks
# ====================
#
# 12. Putting It All Together
# ---------------------------
#
# ::: {#menu4}
# [[Lesson](/documentation/tutorials/2d_tracks/stacking_tracks/lesson){.clean}]{.active}
# [Images](/documentation/tutorials/2d_tracks/stacking_tracks/images){.normal}
# [Configuration](/documentation/tutorials/2d_tracks/stacking_tracks/configuration){.normal}
# :::
#
# In this example, I create an image with a large number of plot tracks
# that include all the types previously discussed. The image looks like a
# heart attack and I don\'t recommend that you create such monstrosities
# for any reasons other than exploring Circos\' syntax.
#
# Several of the idioms in the configuration file are worth exploring in
# detail.
#
# ### placing highlights among data layers
#
# When a highlight is defined as a plot block, you can use the z depth to
# place it anywhere within other data layers.
#
# In this figure, the highlight wedges are drawn ontop of the heatmaps,
# but under the line, histogram, line and tile plots.
#
# ### sampling data randomly
#
# You can choose to hide data points randomly by using a rule that
# incorporates a call to a random number generator. The Perl function
# rand() returns a random number sampled uniformly from the interval
# \[0,1).
#
# ```ini
# <rule>
# condition = rand() < 0.1
# show      = no
# </rule>
# ```
#
# In this case, 10% of the data points, on average, will not appear. Each
# time the image is created, a different set of points will be hidden.
#
# ### formatting data randomly
#
# Along the lines of the previous example, you can apply formatting
# randomly to data. For example, to make 50% of the points, on average,
# red:
#
# ```ini
# <rule>
# condition = rand() < 0.5
# color     = red
# </rule>
# ```
#
# ### hiding heatmap elements
#
# You can hide heatmap elements using the show=no idiom with a size
# condition. You can also subvert the color list and include the
# background color in the list.
#
# ```ini
# <plot>
# type         = heatmap
# ...
# color        = black,grey,vlgrey,white,lgreen,green,dgreen
# ...
# </plot>
# ```
#
# ### adjacent histograms
#
# You can create a floating bar plot by stacking two histograms against
# one another. The outer histogram is oriented \"out\" and the inner one
# is oriented \"in\".
#
# ```ini
# <plot>
# type         = histogram
# ...
# orientation  = in
# r0           = 0.65r
# r1           = 0.75r
# ...
# </plot>
# ```
#
# ```ini
# <plot>
# type         = histogram
# ...
# orientation  = out
# r0           = 0.75r
# r1           = 0.85r
# ...
# </plot>
# ```
#
# ### adjusting ideogram radius
#
# Don\'t forget that you can adjust the radius of individual ideograms, or
# regions.
#
# ```ini
# chromosomes        = hs2[a]:5-35;hs2[b]:40-75;hs2[c]:80-115;hs2[d]:120-155;hs2[e]:160-195;hs2[f]:200-240
# chromosomes_radius = a:0.95r;b:0.9r;c:0.85r;d:0.8r;e:0.75r;f:0.7r
# ```
#
# This is very useful if you need to squeeze in a data track, especially
# outside of the ideogram, but don\'t want to disturb the overall circular
# nature of the plot. In this case, you would shift the ideogram radius in
# by, say, 200px, and then plot a 200px track outside the ideogram.

# %% [markdown]
# ----

# %% [markdown]
# ### Generating the plot produced by this example code
#
# The following two cells will generate the plot. The first cell adjusts the current working directory.

# %%
# %cd ../circos-tutorials-0.67/tutorials/{section}/{sub_pg}/
# Out:
# /home/jovyan/circos-tutorials-0.67/tutorials/6/12

# %%
# %%bash
# ../../../../circos-0.69-6/bin/circos -conf circos.conf
# Out:
# debuggroup summary 0.36s welcome to circos v0.69-6 31 July 2017 on Perl 5.022000
# debuggroup summary 0.36s current working directory /home/jovyan/circos-tutorials-0.67/tutorials/6/12
# debuggroup summary 0.36s command ../../../../circos-0.69-6/bin/circos -conf circos.conf
# debuggroup summary 0.36s loading configuration from file circos.conf
# debuggroup summary 0.36s found conf file circos.conf
# debuggroup summary 0.54s debug will appear for these features: output,summary
# debuggroup summary 0.54s bitmap output image ./circos.png
# debuggroup summary 0.54s SVG output image ./circos.svg
# debuggroup summary 0.54s parsing karyotype and organizing ideograms
# debuggroup summary 0.65s karyotype has 24 chromosomes of total size 3,095,677,436
# debuggroup summary 0.66s applying global and local scaling
# debuggroup summary 0.66s allocating image, colors and brushes
# debuggroup summary 3.47s drawing 1 ideograms of total size 243,199,374
# debuggroup summary 3.47s drawing highlights and ideograms
# debuggroup summary 3.71s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/heatmap.conf
# debuggroup summary 3.71s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/heatmap.conf
# debuggroup summary 3.71s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/heatmap.conf
# debuggroup summary 3.71s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/heatmap.conf
# debuggroup summary 3.71s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/heatmap.conf
# debuggroup summary 3.71s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/scatter.conf
# debuggroup summary 3.71s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/line.conf
# debuggroup summary 3.71s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/line.conf
# debuggroup summary 3.71s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/histogram.conf
# debuggroup summary 3.71s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/histogram.conf
# debuggroup summary 3.71s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/heatmap.conf
# debuggroup summary 3.71s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/tile.conf
# debuggroup summary 3.71s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/tile.conf
# debuggroup summary 3.71s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/tile.conf
# debuggroup summary 3.71s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/highlight.conf
# debuggroup summary 3.72s processing track_0 heatmap /home/jovyan/circos-tutorials-0.67/tutorials/6/12/../../../data/6/snp.number.1mb.txt
# debuggroup summary 3.79s processing track_1 heatmap /home/jovyan/circos-tutorials-0.67/tutorials/6/12/../../../data/6/variation.heatmap.txt
# debuggroup summary 3.96s processing track_2 heatmap /home/jovyan/circos-tutorials-0.67/tutorials/6/12/../../../data/6/rand.1.txt
# debuggroup summary 4.51s processing track_3 heatmap /home/jovyan/circos-tutorials-0.67/tutorials/6/12/../../../data/6/rand.2.txt
# debuggroup summary 5.00s processing track_4 heatmap /home/jovyan/circos-tutorials-0.67/tutorials/6/12/../../../data/6/rand.3.txt
# debuggroup summary 5.55s processing track_5 scatter /home/jovyan/circos-tutorials-0.67/tutorials/6/12/../../../data/6/conservation.avg.txt
# debuggroup summary 5.82s processing track_6 line /home/jovyan/circos-tutorials-0.67/tutorials/6/12/../../../data/6/conservation.p5.txt
# debuggroup summary 6.11s processing track_7 line /home/jovyan/circos-tutorials-0.67/tutorials/6/12/../../../data/6/conservation.p95.txt
# debuggroup summary 6.38s processing track_8 histogram /home/jovyan/circos-tutorials-0.67/tutorials/6/12/../../../data/6/snp.number.500kb.txt
# debuggroup summary 6.56s processing track_9 histogram /home/jovyan/circos-tutorials-0.67/tutorials/6/12/../../../data/6/snp.number.250kb.txt
# debuggroup summary 6.91s processing track_10 heatmap /home/jovyan/circos-tutorials-0.67/tutorials/6/12/../../../data/6/snp.number.1mb.txt
# debuggroup summary 7.00s processing track_11 tile /home/jovyan/circos-tutorials-0.67/tutorials/6/12/../../../data/6/variation.txt
# debuggroup summary 7.23s processing track_12 tile /home/jovyan/circos-tutorials-0.67/tutorials/6/12/../../../data/6/tiles.rand.1.txt
# debuggroup summary 9.99s processing track_13 tile /home/jovyan/circos-tutorials-0.67/tutorials/6/12/../../../data/6/assembly.txt
# debuggroup summary 10.96s processing track_14 highlight /home/jovyan/circos-tutorials-0.67/tutorials/6/12/../../../data/6/highlights.txt
# debuggroup summary 10.97s drawing track_0 heatmap z 0 snp.number.1mb.txt
# debuggroup summary 10.99s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/axis.conf
# debuggroup summary 11.19s drawing track_1 heatmap z 0 variation.heatmap.txt
# debuggroup summary 11.21s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/axis.conf
# debuggroup summary 11.61s drawing track_2 heatmap z 0 rand.1.txt
# debuggroup summary 11.64s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/axis.conf
# debuggroup summary 12.01s drawing track_3 heatmap z 0 rand.2.txt
# debuggroup summary 12.03s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/axis.conf
# debuggroup summary 12.34s drawing track_4 heatmap z 0 rand.3.txt
# debuggroup summary 12.36s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/axis.conf
# debuggroup summary 12.65s drawing track_10 heatmap z 0 snp.number.1mb.txt
# debuggroup summary 12.67s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/axis.conf
# debuggroup summary 12.86s drawing track_14 highlight z 2 highlights.txt
# debuggroup summary 12.86s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/axis.conf
# debuggroup summary 12.92s drawing track_5 scatter z 5 conservation.avg.txt orient out
# debuggroup summary 12.96s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/axis.conf
# debuggroup summary 13.46s drawing track_8 histogram z 10 snp.number.500kb.txt orient out
# debuggroup summary 13.49s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/axis.conf
# debuggroup summary 14.51s drawing track_9 histogram z 10 snp.number.250kb.txt orient in
# debuggroup summary 14.56s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/axis.conf
# debuggroup summary 16.31s drawing track_11 tile z 10 variation.txt orient out
# debuggroup summary 16.32s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/axis.conf
# debuggroup summary 16.63s drawing track_12 tile z 10 tiles.rand.1.txt orient center
# debuggroup summary 16.70s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/axis.conf
# debuggroup summary 21.80s drawing track_13 tile z 10 assembly.txt orient in
# debuggroup summary 21.82s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/axis.conf
# debuggroup summary 25.23s drawing track_6 line z 15 conservation.p5.txt orient out
# debuggroup summary 25.29s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/axis.conf
# debuggroup summary 25.62s drawing track_7 line z 15 conservation.p95.txt orient out
# debuggroup summary 25.67s found conf file /home/jovyan/circos-0.69-6/bin/../etc/tracks/axis.conf
# debuggroup output 26.00s generating output
# debuggroup output 26.99s created PNG image ./circos.png (1540 kb)
# debuggroup output 26.99s created SVG image ./circos.svg (2478 kb)
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781, <F> line 74056.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.
# Use of uninitialized value in subroutine entry at /home/jovyan/circos-0.69-6/bin/../lib/Circos/Configuration.pm line 781.

# %% [markdown]
# View the plot in this page using the following cell.

# %%
from IPython.display import Image
Image("circos.png")

# %% [markdown]
# ----

# %%
next_md = ("Continue on to the next part of the Quick Start series by clicking [here &#10145;]({})</font>.".format(next_nb))
if end_nb:
    next_md = ("End of tutorials.")
#printmd(next_md)
print(next_md) #use this because want to be able to edit the markdown and rendering it with `printmd` diables that
# Out:
# Continue on to the next part of the Quick Start series by clicking [here &#10145;](AxisScaling_Part1.ipynb)</font>.

# %% [markdown]
# ----
