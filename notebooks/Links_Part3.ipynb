# %% [markdown]
# # Part 2 of Links and Relationships: Link Formatting
#
# This page is primarily based on the following page at the Circos documentation site:
#
#
#
# - [3. Link Formatting](????????????)
#
#
#
# That page is found as part number 4 of the ??? part ['Links and Relationships' section](http://circos.ca/documentation/tutorials/quick_start/) of [the larger set of Circos tutorials](http://circos.ca/documentation/tutorials/).
#
#
#
# Go back to Part 2 by clicking [here &#8592;](Links_Part2.ipynb).
#
#
#
# ----
#
#
#
# 5 --- Links and Relationships
# =============================
#
# 3. Link Formatting
# ------------------
#
# ::: {#menu4}
# [[Lesson](/documentation/tutorials/links/formatting/lesson){.clean}]{.active}
# [Images](/documentation/tutorials/links/formatting/images){.normal}
# [Configuration](/documentation/tutorials/links/formatting/configuration){.normal}
# :::
#
# In this example, the image will be created using multiple data sources
# for links. I\'m also going to subvert the record\_limit setting, and in
# combination with z depth, to sample different links from the same data
# file.
#
# In general, if you have multiple data files, each is associated with its
# own [\<link\>]{.syn-block} block.

# %% [markdown]
# ```ini
# <links>
# ```

# %% [markdown]
# ```ini
# # global parameters here
# ...
# ```

# %% [markdown]
# ```ini
# <link>
# file = /path/to/file
# # local parameters for this data set
# ...
# </link>
# ```

# %% [markdown]
# ```ini
# <link>
# file = /path/to/file
# # local parameters for this data set
# ...
# </link>
# ```

# %% [markdown]
# ```ini
# ...
# ```

# %% [markdown]
# ```ini
# </links>
# ```

# %% [markdown]
# When combining multiple link data sets in one image, there are a few
# things to keep in mind.
#
# First, set the z depth for each data set accordingly. Data sets with a
# higher the z depth value are drawn on top of data sets with a lower
# value. In this example, I draw the first 10,000 records from segdup.txt
# in very light grey (z=5), then the first 2,500 records in light grey
# (z=10, thus on top of any z\<10 data), then the first 1,000 records in
# grey (z=15, thus on top of any z\<15 data), and so on.
#
# Second, you can adjust link geometry for each data set. In this example,
# I\'ve modified the crest and bezier radius purity for links drawn from
# the three `segdup.bundle*.txt`{.syn-include} files.
#
# Finally, thickness and color can be effectively used to help layer the
# data. I typically draw links with a lower z value in a light shade of a
# color and with thin lines.
#
#
#
#
# ----
#
# ### Generating the plot produced by this example code
#
#
# The following two cells will generate the plot. The first cell adjusts the current working directory.

# %%
# %cd ../circos-tutorials-0.67/tutorials/5/3/
# Out:
# /home/jovyan/circos-tutorials-0.67/tutorials/5/3

# %%
# %%bash
# ../../../../circos-0.69-6/bin/circos -conf circos.conf
# Out:
# debuggroup summary 0.33s welcome to circos v0.69-6 31 July 2017 on Perl 5.022000
# debuggroup summary 0.34s current working directory /home/jovyan/circos-tutorials-0.67/tutorials/5/3
# debuggroup summary 0.34s command ../../../../circos-0.69-6/bin/circos -conf circos.conf
# debuggroup summary 0.34s loading configuration from file circos.conf
# debuggroup summary 0.34s found conf file circos.conf
# debuggroup summary 0.51s debug will appear for these features: output,summary
# debuggroup summary 0.51s bitmap output image ./circos.png
# debuggroup summary 0.51s SVG output image ./circos.svg
# debuggroup summary 0.51s parsing karyotype and organizing ideograms
# debuggroup summary 0.63s karyotype has 24 chromosomes of total size 3,095,677,436
# debuggroup summary 0.64s applying global and local scaling
# debuggroup summary 0.64s allocating image, colors and brushes
# debuggroup summary 2.62s drawing 3 ideograms of total size 690,472,427
# ...

# %% [markdown]
# View the plot in this page using the following cell.

# %%
from IPython.display import Image
Image("circos.png")

# %% [markdown]
# ----
#
# Continue on to the next part of the Links and Relationships series by clicking [here &#10145;](Links_Part4.ipynb).
#
# ----
