# %% [markdown]
# # Part 11 of 2D Data Tracks: Connectors
#
# This page is primarily based on the following page at the Circos documentation site:
#
#
#
# - [11. Connectors](????????????)
#
#
#
# That page is found as part number 4 of the ??? part ['2D Data Tracks' section](http://circos.ca/documentation/tutorials/quick_start/) of [the larger set of Circos tutorials](http://circos.ca/documentation/tutorials/).
#
#
#
# Go back to Part 10 by clicking [here &#8592;](2d_data_tracks_Part10.ipynb).
#
#
#
# ----
#
#
#
# 6 --- 2D Data Tracks
# ====================
#
# 11. Connectors
# --------------
#
# ::: {#menu4}
# [[Lesson](/documentation/tutorials/2d_tracks/connectors/lesson){.clean}]{.active}
# [Images](/documentation/tutorials/2d_tracks/connectors/images){.normal}
# [Configuration](/documentation/tutorials/2d_tracks/connectors/configuration){.normal}
# :::
#
# Connectors are articulated line segments that relate two positions on an
# ideogram between two radial positions.
#
# The definition of a connector track is done as a plot type

# %% [markdown]
# ```ini
# <plot>
# ```

# %% [markdown]
# ```ini
# type = connector
# file = data/6/connectors.txt
# ```

# %% [markdown]
# ```ini
# r0   = 0.8925r
# r1   = 0.999r
# ```

# %% [markdown]
# ```ini
# connector_dims = 0,0.3,0.4,0.3,0
# ```

# %% [markdown]
# ```ini
# thickness = 2
# color     = black
# </plot>
# ```

# %% [markdown]
# The data file defines the positions at r0 and r1 to be linked by lines

# %% [markdown]
# ```ini
# # connectors.txt
# ...
# hs22 15116257 16046604
# hs22 15136864 16056568
# ...
# ```

# %% [markdown]
# The example images in this section show how the connector\_dims
# parameter controls the shape of the connector line. The line has five
# segments and the five connector\_dims parameters define the size of each
# of the segments relative to (r1-r0).
#
#
#
#
# ----
#
# ### Generating the plot produced by this example code
#
#
# The following two cells will generate the plot. The first cell adjusts the current working directory.

# %%
# %cd ../circos-tutorials-0.67/tutorials/6/11/
# Out:
# /home/jovyan/circos-tutorials-0.67/tutorials/6/11

# %%
# %%bash
# ../../../../circos-0.69-6/bin/circos -conf circos.conf
# Out:
# debuggroup summary 0.35s welcome to circos v0.69-6 31 July 2017 on Perl 5.022000
# debuggroup summary 0.36s current working directory /home/jovyan/circos-tutorials-0.67/tutorials/6/11
# debuggroup summary 0.36s command ../../../../circos-0.69-6/bin/circos -conf circos.conf
# debuggroup summary 0.36s loading configuration from file circos.conf
# debuggroup summary 0.36s found conf file circos.conf
# debuggroup summary 0.56s debug will appear for these features: output,summary
# debuggroup summary 0.56s bitmap output image ./circos.png
# debuggroup summary 0.56s SVG output image ./circos.svg
# debuggroup summary 0.56s parsing karyotype and organizing ideograms
# debuggroup summary 0.66s karyotype has 24 chromosomes of total size 3,095,677,436
# debuggroup summary 0.67s applying global and local scaling
# debuggroup summary 0.67s allocating image, colors and brushes
# debuggroup summary 2.72s drawing 1 ideograms of total size 35,000,000
# ...

# %% [markdown]
# View the plot in this page using the following cell.

# %%
from IPython.display import Image
Image("circos.png")

# %% [markdown]
# ----
#
# Continue on to the next part of the 2D Data Tracks series by clicking [here &#10145;](2d_data_tracks_Part12.ipynb).
#
# ----
