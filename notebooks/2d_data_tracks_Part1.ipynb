# %% [markdown]
# # Part 1 of 2D Data Tracks: Scatter Plots
#
# This page is primarily based on the following page at the Circos documentation site:
#
#
#
# - [1. Scatter Plots](????????????)
#
#
#
# That page is the first part of the ??? part ['2D Data Tracks' section](http://circos.ca/documentation/tutorials/quick_start/) of [the larger set of Circos tutorials](http://circos.ca/documentation/tutorials/).
#
#
#
# Go back to the end of the previous section by clicking [here &#8592;](Links_Part10.ipynb).
#
#
#
# ----
#
#
#
# 6 --- 2D Data Tracks
# ====================
#
# 1. Scatter Plots
# ----------------
#
# ::: {#menu4}
# [[Lesson](/documentation/tutorials/2d_tracks/scatter_plots/lesson){.clean}]{.active}
# [Images](/documentation/tutorials/2d_tracks/scatter_plots/images){.normal}
# [Configuration](/documentation/tutorials/2d_tracks/scatter_plots/configuration){.normal}
# :::
#
# Syntax for 2D data types is similar to that for links. You define all 2D
# plots within \>plots\< block, with one plot per \<plot\> block. Within a
# plot block, you define formatting and data file for the plot, and can
# insert optional \>rules\> block that contains multiple \<rule\> blocks.
#
# There are several 2D data types and the scatter plot is one. The image
# for this example contains three scatter plots, all derived from the same
# data file. Each plot is formatted slightly differently. The data are SNP
# density for windows of 100kb (number of SNPs from dbSNP per base).
#
# ### default settings
#
# Each plot type has default settings which you can find in `etc/tracks`.
# For example,

# %% [markdown]
# ```ini
# # etc/tracks/scatter.conf
# glyph            = circle
# glyph_size       = 10
# color            = grey
# stroke_color     = black
# stroke_thickness = 0
# r1               = 0.79r
# r0               = 0.7r
# orientation      = out
# ```

# %% [markdown]
# These settings are applied to every \<plot\> block of `type=scatter`.
# YOu can undefine a setting using `undef`,

# %% [markdown]
# ```ini
# stroke_color = undef
# ```

# %% [markdown]
# ### basic scatter plot syntax
#
# 2D data types share have the same format parameters, with a few
# exceptions. For the scatter plot, a basic definition might look like
# this

# %% [markdown]
# ```ini
# <plots>
# ```

# %% [markdown]
# ```ini
# <plot>
# ```

# %% [markdown]
# ```ini
# show  = yes
# type  = scatter
# ```

# %% [markdown]
# ```ini
# file  = data/6/snp.density.txt
# r1    = 0.75r
# r0    = 0.90r
# max   = 1.0
# min   = 0.0
# ```

# %% [markdown]
# ```ini
# glyph            = rectangle
# glyph_size       = 8
# color            = red
# stroke_color     = dred
# stroke_thickness = 1
# ```

# %% [markdown]
# ```ini
# </plot>
# ```

# %% [markdown]
# ```ini
# </plots>
# ```

# %% [markdown]
# The parameters are
#
# -   `show` - as with highlights or links, determines whether to draw the

# %% [markdown]
# ```ini
# plot or not
# ```

# %% [markdown]
# -   `type` - determines the type of plot and can be one of scatter,

# %% [markdown]
# ```ini
# line, histogram, heatmap, etc.
# ```

# %% [markdown]
# -   `file` - file that contains plot data
# -   `min/max` - the range of the plot axis, data outside this range are

# %% [markdown]
# ```ini
# clipped
# ```

# %% [markdown]
# -   `r0/r1` - the inner and outer radius of the plot track, which may be

# %% [markdown]
# ```ini
# formatted in absolute or relative (or mix) form, just like for
# highlights
# ```

# %% [markdown]
# -   `glyph` - shape of glyph to use for the scatter plot and can be one

# %% [markdown]
# ```ini
# of circle, rectangle, or triangle
# ```

# %% [markdown]
# -   `glyph_size` - size of the glyph, in pixels
# -   `color` - if used, the the glyph will be solid and of this color
# -   `stroke_color` - if used, the glyph will have an outline of this

# %% [markdown]
# ```ini
# color
# ```

# %% [markdown]
# -   `stroke_thickness` - if used, the glyph\'s outline will have this

# %% [markdown]
# ```ini
# thickness, in pixels
# ```

# %% [markdown]
# The data file format for 2D plots is

# %% [markdown]
# ```ini
# chr start end value options
# ```

# %% [markdown]
# Note that a value is associated with an explicit span, and not a single
# base pair position. For example,

# %% [markdown]
# ```ini
# # value 0.005 at span 1000-2000
# hs1 1000 2000 0.005
# # value 0.010 at span 2001-2001, e.g. a single base position
# hs1 2001 2001 0.010
# ```

# %% [markdown]
# The reason why Circos uses start *and* end positions for the data file
# is to maintain consistency between data and link files. Glyphs are drawn
# at the middle of the span. Thus, in the above example, the glyphs would
# be drawn at positions 1,500 and 2,001.
#
# Points whose values fall outside of the min/max range defined in the
# plot parameters are not drawn. You do not need to write rules to exclude
# these points.
#
# ### plot background
#
# The `r0` and `r1` parameters define the radial start and end positions
# of the plot track. You can optionally add background fill(s) to the
# track with a `<backgrounds>` block. using the following parameters

# %% [markdown]
# ```ini
# <backgrounds>
# <background>
# color = vvlgrey
# </background>
# </backgrounds>
# ```

# %% [markdown]
# By defining several `<background>` blocks, you can stripe and layer the
# background fills. Use `y0/y1` to define the radial extent of the fill.

# %% [markdown]
# ```ini
# <backgrounds>
# <background>
# color     = vlgrey
# # absolute fill range
# y1        = 0.5
# y0        = 0
# </background>
# <background>
# color     = vlred
# # relative fill range
# y1        = 1r
# y0        = 0.75r
# </background>
# </backgrounds>
# ```

# %% [markdown]
# ### plot axis
#
# You can draw a set of y-axis grid lines within your plot track using the
# `<axes>` block.

# %% [markdown]
# ```ini
# <axes>
# <axis>
# color     = grey
# thickness = 1
# spacing   = 0.05r
# </axis>
# </axes>
# ```

# %% [markdown]
# The axes are a series of concentric arcs with a given `spacing`. The
# spacing value can be absolute or relative.
#
# ### plot format rules
#
# Formatting rules work for plots in the same manner as for links. Within
# the condition field, use `var(value)` to represent the data value for a
# particular point.
#
# For example,

# %% [markdown]
# ```ini
# <rule>
# condition    = var(value) > 0.5
# stroke_color = dgreen
# color        = green
# glyph        = rectangle
# glyph_size   = 6
# </rule>
# ```

# %% [markdown]
# would turn all points whose value is larger than 0.5 to be rectangles of
# size 6 with a dark green outline and green fill.
#
# You can hide certain data points by setting `show=no` within the rule.
#
#
#
#
# ----
#
# ### Generating the plot produced by this example code
#
#
# The following two cells will generate the plot. The first cell adjusts the current working directory.

# %%
# %cd ../circos-tutorials-0.67/tutorials/6/1/
# Out:
# /home/jovyan/circos-tutorials-0.67/tutorials/6/1

# %%
# %%bash
# ../../../../circos-0.69-6/bin/circos -conf circos.conf
# Out:
# debuggroup summary 0.38s welcome to circos v0.69-6 31 July 2017 on Perl 5.022000
# debuggroup summary 0.40s current working directory /home/jovyan/circos-tutorials-0.67/tutorials/6/1
# debuggroup summary 0.40s command ../../../../circos-0.69-6/bin/circos -conf circos.conf
# debuggroup summary 0.40s loading configuration from file circos.conf
# debuggroup summary 0.40s found conf file circos.conf
# debuggroup summary 0.57s debug will appear for these features: output,summary
# debuggroup summary 0.57s bitmap output image ./circos.png
# debuggroup summary 0.57s SVG output image ./circos.svg
# debuggroup summary 0.57s parsing karyotype and organizing ideograms
# debuggroup summary 0.68s karyotype has 24 chromosomes of total size 3,095,677,436
# debuggroup summary 0.68s applying global and local scaling
# debuggroup summary 0.70s allocating image, colors and brushes
# debuggroup summary 3.00s drawing 3 ideograms of total size 690,472,427
# ...

# %% [markdown]
# View the plot in this page using the following cell.

# %%
from IPython.display import Image
Image("circos.png")

# %% [markdown]
# ----
#
# Continue on to the next part of the 2D Data Tracks series by clicking [here &#10145;](2d_data_tracks_Part2.ipynb).
#
# ----
