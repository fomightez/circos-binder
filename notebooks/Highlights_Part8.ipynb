# %% [markdown]
# # Part 8 of Highlights: Recipe 3 - Plot Axis Range Highlights
#
# This page is primarily based on the following page at the Circos documentation site:
#
#
#
# - [8. Recipe 3 - Plot Axis Range Highlights](????????????)
#
#
#
# That page is found as part number 4 of the ??? part ['Highlights' section](http://circos.ca/documentation/tutorials/quick_start/) of [the larger set of Circos tutorials](http://circos.ca/documentation/tutorials/).
#
#
#
# Go back to Part 7 by clicking [here &#8592;](Highlights_Part7.ipynb).
#
#
#
# ----
#
#
#
# 3 --- Highlights
# ================
#
# 8. Recipe 3 - Plot Axis Range Highlights
# ----------------------------------------
#
# ::: {#menu4}
# [[Lesson](/documentation/tutorials/highlights/recipe3/lesson){.clean}]{.active}
# [Images](/documentation/tutorials/highlights/recipe3/images){.normal}
# [Configuration](/documentation/tutorials/highlights/recipe3/configuration){.normal}
# :::
#
# In this section, I\'ll look ahead and show how you can use highlights to
# annotate 2D data plots (e.g. scatter plots).
#
# By defining highlights to span the entire data domain (e.g. entire
# genome), you can draw multiple instances of the highlight using
# different colors and radial positions, in effect setting up a set of
# concentric circles that provide radial axis highlights.
#
# By drawing a scatter plot, for example, and synchronizing the radial
# extent of the scatter plot with the position of the highlights, you can
# draw attention to outlying data in your scatter plot.

# %% [markdown]
# ```ini
# <highlight>
# file       = data/3/chr.highlights.colourless.txt
# r0 = 0.715r
# r1 = 0.725r
# fill_color = lred
# </highlight>
# ```

# %% [markdown]
# ```ini
# <highlight>
# file       = data/3/chr.highlights.colourless.txt
# r0 = 0.725r
# r1 = 0.75r
# fill_color = lorange
# </highlight>
# ```

# %% [markdown]
# ```ini
# <highlight>
# file       = data/3/chr.highlights.colourless.txt
# r0 = 0.75r
# r1 = 0.80r
# fill_color = lyellow
# </highlight>
# ```

# %% [markdown]
# ```ini
# <highlight>
# file       = data/3/chr.highlights.colourless.txt
# r0 = 0.8r
# r1 = 0.9r
# fill_color = lgrey
# </highlight>
# ```

# %% [markdown]
# ```ini
# <highlight>
# file       = data/3/chr.highlights.colourless.txt
# r0 = 0.9r
# r1 = 0.95r
# fill_color = lyellow
# </highlight>
# ```

# %% [markdown]
# ```ini
# <highlight>
# file       = data/3/chr.highlights.colourless.txt
# r0 = 0.95r
# r1 = 0.975r
# fill_color = lorange
# </highlight>
# ```

# %% [markdown]
# ```ini
# <highlight>
# file       = data/3/chr.highlights.colourless.txt
# r0 = 0.975r
# r1 = 0.985r
# fill_color = lred
# </highlight>
# ```

# %% [markdown]
# ----
#
# ### Generating the plot produced by this example code
#
#
# The following two cells will generate the plot. The first cell adjusts the current working directory.

# %%
# %cd ../circos-tutorials-0.67/tutorials/3/8/
# Out:
# /home/jovyan/circos-tutorials-0.67/tutorials/3/8

# %%
# %%bash
# ../../../../circos-0.69-6/bin/circos -conf circos.conf
# Out:
# debuggroup summary 0.45s welcome to circos v0.69-6 31 July 2017 on Perl 5.022000
# debuggroup summary 0.46s current working directory /home/jovyan/circos-tutorials-0.67/tutorials/3/8
# debuggroup summary 0.46s command ../../../../circos-0.69-6/bin/circos -conf circos.conf
# debuggroup summary 0.46s loading configuration from file circos.conf
# debuggroup summary 0.46s found conf file circos.conf
# debuggroup summary 0.62s debug will appear for these features: output,summary
# debuggroup summary 0.62s bitmap output image ./circos.png
# debuggroup summary 0.62s SVG output image ./circos.svg
# debuggroup summary 0.63s parsing karyotype and organizing ideograms
# debuggroup summary 0.72s karyotype has 24 chromosomes of total size 3,095,677,436
# debuggroup summary 0.73s applying global and local scaling
# debuggroup summary 0.74s allocating image, colors and brushes
# debuggroup summary 2.66s drawing 6 ideograms of total size 1,233,657,033
# ...

# %% [markdown]
# View the plot in this page using the following cell.

# %%
from IPython.display import Image
Image("circos.png")

# %% [markdown]
# ----
#
# Continue on to the next part of the Highlights series by clicking [here &#10145;](Highlights_Part9.ipynb).
#
# ----
